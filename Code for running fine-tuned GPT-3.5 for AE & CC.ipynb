# %% [markdown]
# <a href="https://colab.research.google.com/github/AnonymousPaperSubmissions/SPORTMR-D-24-00043/blob/main/Code%20for%20running%20fine-tuned%20GPT-3.5%20for%20AE%20%26%20CC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **`ft:gpt-3.5-turbo-1106:qian:cxae:8kZXONLd`**

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.14.3-py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 7.2 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 openai-1.14.3

# %%
import openai
import pandas as pd

# Set up OpenAI API Key securely
from google.colab import userdata
api_key = userdata.get('GPT-3.5_KEY')
client = openai.client(api_key=api_key)

# Load the CSV file
df = pd.read_csv('/content/drive/MyDrive/Fine-tune/INF/DATA/Reviews14_errors.csv')

# Create a new column in the DataFrame to store the results
df['Aspect'] = ''

# Define the system prompt
system_prompt = ("""
    You are an expert in college football, specializing in analyzing Tripadvisor reviews of college football stadiums, focusing on game day experiences.
    Each review consists of sentences that need to be treated individually. Within these sentences, identify various aspects of the game day experience, noting that a single aspect can have multiple descriptions.
    For aspect extraction in each sentence of a review, the process must be followed carefully. Ensure each step is taken one at a time for optimal clarity and results:
    1. Analyze each sentence as a separate unit.
    2. Identify the different aspects of the game day experience mentioned.
    3. For aspects with multiple descriptions within the same sentence, list each description as a separate entry, including the aspect in the detail for clarity.
    4. Extract each aspect and its corresponding detailed description.
    5. Format this information in a JSON structure using '''Aspect_i''' and '''Details_i''' as keys, incrementing '''i''' for each new aspect or unique description.
    """
)

for index, row in df.iterrows():
    if pd.notna(row['Text']):
        conversation = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": row['Text']}
        ]

        try:
            response = client.chat.completions.create(
                model="ft:gpt-3.5-turbo-1106:qian:cxae:8kZXONLd",
                messages=conversation,
                temperature=0,
                max_tokens=2048
            )
                #response_format={ "type": "json_object" }

            # Assuming the response is an object with attributes, we use dot notation
            # If this raises an error, then your environment may be different and require dictionary access
            content = response.choices[0].message.content

            # Debug: Print the response
            print(f"Index {index} - Response: {content}")

            # Assign the response to the DataFrame
            df.at[index, 'Aspect'] = content

        except Exception as e:
            print(f"Error processing index {index}: {e}")
    else:
        print(f"Skipping index {index}: 'Text' column is NaN")

# Debug: Print the DataFrame before saving
print(df.head())

# Save the DataFrame
df.to_csv('/content/drive/MyDrive/Fine-tune/INF/OUTPUT/Reviews14_AE_errors.csv', index=False)

# %% [markdown]
# **ft:gpt-3.5-turbo-1106:qian:cxcc:8mNAEN0D**

# %%
# !pip install openai

# %%
import openai as OpenAI
import pandas as pd
from google.colab import userdata

# Set up OpenAI API Key securely
api_key = userdata.get('GPT-3.5_KEY')
client = OpenAI.Client(api_key=api_key)

# Load the CSV file
df = pd.read_csv('/content/drive/MyDrive/Fine-tune/INF/DATA/Reviews14_AE_CC_errors.csv')

# Create a new column in the DataFrame to store the results
df['Label1'] = ''

# Define the system prompt
system_prompt = ("""
    You are an expert in college football, specializing in categorizing aspects of the college football game day experience, identified from Tripadvisor online reviews of college football stadiums.
    Each identified aspect ('''Aspect_i''') has a corresponding description ('''Details_i''') that you will use to determine its appropriate category.
    The categories are 'Core', 'Functional', 'Emotional', 'Monetary', 'Social', 'Safety', and 'Others'.
    Your task is to analyze each aspect's description and classify it accordingly.
    Ensure each step is taken one at a time for optimal clarity and results:
    1. Examine the description ('''Details_i''') of each aspect ('''Aspect_i''').
    2. Classify '''Aspect_i''' into one of the following categories based on '''Details_i''':
    'Core': Sports-related attributes (e.g., team dynamics, game quality).
    'Functional': utilitarian services (e.g., facilities, concessions, parking).
    'Emotional': Feelings or emotional states (e.g., excitement, thrill).
    'Monetary': Pricing aspects (e.g., affordability, value for money).
    'Social': Interpersonal and community aspects (e.g., fan interactions, traditions).
    'Safety': Security and safety experiences (e.g., measures, feelings of safety).
    'Others': Aspects unrelated to the college football game day experience or that do not fit into the other categories, such as general comments about the city or weather conditions.
    3. Format this classification into a JSON structure using '''Aspect_i''' and '''Label_i''' as keys, incrementally assigning '''i''' for each aspect.
"""
)

for index, row in df.iterrows():
    if pd.notna(row['Aspect1']):
        conversation = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": row['Aspect1']}
        ]

        try:
            response = client.chat.completions.create(
                model="ft:gpt-3.5-turbo-1106:qian:cxcc:8mNAEN0D",
                messages=conversation,
                temperature=0,
                max_tokens=2048
            )
            #response_format={ "type": "json_object" }

            # Assuming the response is an object with attributes, we use dot notation
            # If this raises an error, then your environment may be different and require dictionary access
            content = response.choices[0].message.content

            # Debug: Print the response
            print(f"Index {index} - Response: {content}")

            # Assign the response to the DataFrame
            df.at[index, 'Label1'] = content

        except Exception as e:
            print(f"Error processing index {index}: {e}")
    else:
        print(f"Skipping index {index}: 'Text' column is NaN")

# Debug: Print the DataFrame before saving
print(df.head())

# Save the DataFrame
df.to_csv('/content/drive/MyDrive/Fine-tune/INF/OUTPUT/Reviews14_AE_CC_errors.csv', index=False)
# Out:
# Index 0 - Response: [ { '''Aspect_1''': '''football games''', '''Label_1''': '''Core''' }, { '''Aspect_2''': '''atmosphere''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''"Most Exciting 25 seconds in College Football"''', '''Label_3''': '''Emotional''' } ]
# Index 1 - Response: [ { '''Aspect_1''': '''recommendation''', '''Label_1''': '''Monetary''' }, { '''Aspect_2''': '''synergy within the stadium''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''fan''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''event''', '''Label_4''': '''Others''' } ]
# Index 2 - Response: [ { '''Aspect_1''': '''Memorial Stadium''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''food and traffic''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''upper deck''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''lower deck''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''view''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''South stands''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''West End Zone''', '''Label_7''': '''Functional''' } ]
# Index 3 - Response: [ { '''Aspect_1''': '''atmosphere''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''fans''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''tailgating''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''accessibility''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''stadium food''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''food choices''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''beer''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''fans leaving''', '''Label_8''': '''Social''' } ]
# Index 4 - Response: [ { '''Aspect_1''': '''seats''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''rain''', '''Label_2''': '''Others''' }, { '''Aspect_3''': '''visit''', '''Label_3''': '''Emotional''' }, { '''Aspect_4''': '''Clemson run down the hill''', '''Label_4''': '''Core''' }, { '''Aspect_5''': '''loss''', '''Label_5''': '''Emotional''' }, { '''Aspect_6''': '''field''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''Howard's Rock''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''Clemson''', '''Label_8''': '''Social''' }, { '''Aspect_9''': '''people''', '''Label_9''': '''Social''' }, { '''Aspect_10''': '''national championship''', '''Label_10''': '''Core''' } ]
# Index 5 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''spirit''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''Clemson home game''', '''Label_3''': '''Social''' } ]
# Index 6 - Response: [ { '''Aspect_1''': '''place''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''campus''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''atmosphere''', '''Label_3''': '''Emotional''' }, { '''Aspect_4''': '''tradition''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''Clemson''', '''Label_5''': '''Social''' } ]
# Index 7 - Response: [ { '''Aspect_1''': '''recommendation''', '''Label_1''': '''Others''' }, { '''Aspect_2''': '''history and tradition''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''tailgate''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''seats''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''Upper Deck seats''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''Tigers''', '''Label_6''': '''Social''' } ]
# Index 8 - Response: [ { '''Aspect_1''': '''game''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''Clemson fans''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''football team's entrance''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''game experience''', '''Label_4''': '''Emotional''' }, { '''Aspect_5''': '''seats''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''stadium''', '''Label_6''': '''Emotional''' }, { '''Aspect_7''': '''access to stadium levels''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''reentry''', '''Label_8''': '''Safety''' }, { '''Aspect_9''': '''recommendation''', '''Label_9''': '''Emotional''' } ]
# Index 9 - Response: [ { '''Aspect_1''': '''team buses''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''Howard's Rock''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''run down the hill''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''balloons''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''tiger fans''', '''Label_5''': '''Social''' } ]
# Index 10 - Response: [ { '''Aspect_1''': '''atmosphere''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''game''', '''Label_2''': '''Core''' }, { '''Aspect_3''': '''fans on the field''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''Howard's Rock''', '''Label_4''': '''Social''' } ]
# Index 11 - Response: [ { '''Aspect_1''': '''Clemson''', '''Label_1''': '''Social''' }, { '''Aspect_2''': '''tailgaiting experience''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''Memorial Stadium''', '''Label_3''': '''Core''' } ]
# Index 12 - Response: [ { '''Aspect_1''': '''Stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''nickname''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''visit''', '''Label_3''': '''Others''' } ]
# Index 13 - Response: [ { '''Aspect_1''': '''atmosphere''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''fans''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''tradition''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''tailgating''', '''Label_4''': '''Social''' } ]
# Index 14 - Response: [ { '''Aspect_1''': '''football game''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''football stadium''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''accessibility''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''attraction''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''upper deck seats''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''food''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''box score''', '''Label_7''': '''Functional''' } ]
# Index 15 - Response: [ { '''Aspect_1''': '''football game''', '''Label_1''': '''Emotional''' } ]
# Index 16 - Response: [ { '''Aspect_1''': '''team''', '''Label_1''': '''Core''' }, { '''Aspect_2''': '''venue upgrades''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''restrooms, concessions, field and stadium upgrades''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''tickets and parking''', '''Label_4''': '''Monetary''' }, { '''Aspect_5''': '''tailgating''', '''Label_5''': '''Social''' }, { '''Aspect_6''': '''student body''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''fans''', '''Label_7''': '''Social''' } ]
# Index 17 - Response: [ { '''Aspect_1''': '''seating''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''security''', '''Label_2''': '''Safety''' }, { '''Aspect_3''': '''security''', '''Label_3''': '''Safety''' }, { '''Aspect_4''': '''package''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''purses''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''parking''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''campus''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''return''', '''Label_8''': '''Others''' }, { '''Aspect_9''': '''game''', '''Label_9''': '''Core''' }, { '''Aspect_10''': '''travel''', '''Label_10''': '''Others''' } ]
# Index 18 - Response: [ { '''Aspect_1''': '''remodeled stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''field, score board and walls''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''parking garage''', '''Label_3''': '''Functional''' } ]
# Index 19 - Response: [ { '''Aspect_1''': '''season tickets''', '''Label_1''': '''Monetary''' }, { '''Aspect_2''': '''seats''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''seats''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''location''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''view''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''football family''', '''Label_6''': '''Social''' }, { '''Aspect_7''': '''parking''', '''Label_7''': '''Functional''' } ]
# Index 20 - Response: [ { '''Aspect_1''': '''football games''', '''Label_1''': '''Social''' }, { '''Aspect_2''': '''changes''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''FSU game''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''fireworks display''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''campus visit''', '''Label_5''': '''Social''' } ]
# Index 21 - Response: [ { '''Aspect_1''': '''visit''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''dream''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''tailgating''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''game''', '''Label_4''': '''Core''' }, { '''Aspect_5''': '''game''', '''Label_5''': '''Core''' }, { '''Aspect_6''': '''experience''', '''Label_6''': '''Emotional''' }, { '''Aspect_7''': '''experience''', '''Label_7''': '''Emotional''' } ]
# Index 22 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''tradition''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''seating''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''stadium food''', '''Label_4''': '''Functional''' } ]
# Index 23 - Response: [ { '''Aspect_1''': '''look''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''atmosphere''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''kids''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''traditions''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''tour''', '''Label_5''': '''Functional''' } ]
# Index 24 - Response: [ { '''Aspect_1''': '''stadiums''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''Talahassee campus''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''womens' bathrooms''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''concession areas''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''stadium staff''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''experience''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''game''', '''Label_7''': '''Core''' }, { '''Aspect_8''': '''Tennessee's stadium''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''recommendation''', '''Label_9''': '''Functional''' } ]
# Index 25 - Response: [ { '''Aspect_1''': '''seats''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''seats''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''food''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''bathrooms''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''cover''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''seats''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''vibe''', '''Label_7''': '''Emotional''' } ]
# Index 26 - Response: [ { '''Aspect_1''': '''recommendation''', '''Label_1''': '''Others''' }, { '''Aspect_2''': '''tradition''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''tradition''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''game''', '''Label_4''': '''Core''' } ]
# Index 27 - Response: [ { '''Aspect_1''': '''getting there''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''pre-game activities''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''hotels''', '''Label_3''': '''Monetary''' }, { '''Aspect_4''': '''tickets''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''parking''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''pre-game festivities''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''recommendation''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''parking ticket''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''walking to the stadium''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''bathrooms''', '''Label_10''': '''Functional''' }, { '''Aspect_11''': '''pre-game festivities''', '''Label_11''': '''Functional''' }, { '''Aspect_12''': '''memorabilia and collectibles''', '''Label_12''': '''Functional''' }, { '''Aspect_13''': '''pre-game events in the stadium''', '''Label_13''': '''Functional''' }, { '''Aspect_14''': '''seats and the game''', '''Label_14''': '''Functional''' }, { '''Aspect_15''': '''experience''', '''Label_15''': '''Emotional''' }, { '''Aspect_16''': '''recommendation''', '''Label_16''': '''Functional''' } ]
# Index 28 - Response: [ { '''Aspect_1''': '''pop corn''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''salt''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''food and concessions''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''outside vendors''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''soda''', '''Label_5''': '''Functional''' } ]
# Index 29 - Response: [ { '''Aspect_1''': '''staff and facilities''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''fans in attendance''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''student section''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''frustration''', '''Label_4''': '''Emotional''' }, { '''Aspect_5''': '''likelihood of traveling''', '''Label_5''': '''Others''' } ]
# Index 30 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''seats''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''jumbotron''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''walk''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''atmosphere''', '''Label_5''': '''Emotional''' }, { '''Aspect_6''': '''college football experience''', '''Label_6''': '''Core''' }, { '''Aspect_7''': '''drum corp, cheerleaders, and dance team''', '''Label_7''': '''Social''' } ]
# Index 31 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''seats''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''concession stands''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''events''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''hotdog''', '''Label_5''': '''Functional''' } ]
# Index 32 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''Grant Field at Bobby Dodd''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''parking''', '''Label_3''': '''Functional''' } ]
# Index 33 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''iron work''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''facilities''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''North end''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''incline''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''seats''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''college atmosphere''', '''Label_7''': '''Social''' }, { '''Aspect_8''': '''upper deck''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''parking''', '''Label_9''': '''Functional''' } ]
# Index 34 - Response: [ { '''Aspect_1''': '''facilities''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''access''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''restrooms''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''ladies restrooms''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''concession lines''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''collegiate campus''', '''Label_6''': '''Others''' }, { '''Aspect_7''': '''metropolitan Atlanta''', '''Label_7''': '''Others''' } ]
# Index 35 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''campus''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''campus''', '''Label_3''': '''Social''' } ]
# Index 36 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''food concessions and toilets''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''food and drink options''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''employees''', '''Label_4''': '''Functional''' } ]
# Index 37 - Response: [ { '''Aspect_1''': '''game''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''car park''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''tailgate party''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''atmosphere''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''stadium''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''facilities''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''food outlets''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''tickets''', '''Label_8''': '''Monetary''' }, { '''Aspect_9''': '''SuperBowl''', '''Label_9''': '''Monetary''' }, { '''Aspect_10''': '''experience''', '''Label_10''': '''Emotional''' } ]
# Index 38 - Response: [ { '''Aspect_1''': '''pre-match tailgate party''', '''Label_1''': '''Social''' }, { '''Aspect_2''': '''entertainment and bars''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''bars and places to eat''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''game''', '''Label_4''': '''Core''' }, { '''Aspect_5''': '''transport''', '''Label_5''': '''Functional''' } ]
# Index 39 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''tailgating''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''employees''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''security lines''', '''Label_4''': '''Safety''' }, { '''Aspect_5''': '''stadium rules''', '''Label_5''': '''Safety''' }, { '''Aspect_6''': '''Guest Services Headquarters''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''seats''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''roof''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''rain''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''visitor side''', '''Label_10''': '''Functional''' } ]
# Index 40 - Response: [ { '''Aspect_1''': '''game''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''venue''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''Dolphins store''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''employees''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''Dolphins store''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''Dolphins store''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''ride''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''ride share''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''ride share''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''ride share''', '''Label_10''': '''Functional''' }, { '''Aspect_11''': '''ride share''', '''Label_11''': '''Safety''' }, { '''Aspect_12''': '''Lyft/Uber''', '''Label_12''': '''Monetary''' }, { '''Aspect_13''': '''driver''', '''Label_13''': '''Functional''' }, { '''Aspect_14''': '''driver''', '''Label_14''': '''Functional''' }, { '''Aspect_15''': '''safety''', '''Label_15''': '''Safety''' }, { '''Aspect_16''': '''taxi driver''', '''Label_16''': '''Monetary''' }, { '''Aspect_17''': '''experience''', '''Label_17''': '''Functional''' }, { '''Aspect_18''': '''stadium''', '''Label_18''': '''Others''' }, { '''Aspect_19''': '''parking''', '''Label_19''': '''Functional''' } ]
# Index 41 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''food''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''beer''', '''Label_3''': '''Monetary''' }, { '''Aspect_4''': '''restrooms and parking''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''big screens''', '''Label_5''': '''Functional''' } ]
# Index 42 - Response: [ { '''Aspect_1''': '''spaces''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''experience''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''meeting''', '''Label_3''': '''Social''' } ]
# Index 43 - Response: [ { '''Aspect_1''': '''Hard Rock Stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''Club seats''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''prices''', '''Label_3''': '''Monetary''' }, { '''Aspect_4''': '''"First Down" cheer''', '''Label_4''': '''Social''' } ]
# Index 44 - Response: [ { '''Aspect_1''': '''facilities''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''recommendation''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''security''', '''Label_3''': '''Safety''' }, { '''Aspect_4''': '''crowds''', '''Label_4''': '''Safety''' }, { '''Aspect_5''': '''atmosphere''', '''Label_5''': '''Safety''' }, { '''Aspect_6''': '''safety''', '''Label_6''': '''Safety''' } ]
# Index 45 - Response: [ { '''Aspect_1''': '''game''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''stadium''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''display boards''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''seats''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''field turf''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''Kenan''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''facade and facilities''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''club spaces''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''seatbacks''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''recommendation''', '''Label_10''': '''Emotional''' } ]
# Index 46 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''comparison''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''Tar Heel Blue''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''crowd''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''staff''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''seats''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''food''', '''Label_7''': '''Monetary''' }, { '''Aspect_8''': '''hot day''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''parking''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''experience''', '''Label_10''': '''Emotional''' } ]
# Index 47 - Response: [ { '''Aspect_1''': '''big screen''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''football games''', '''Label_2''': '''Core''' }, { '''Aspect_3''': '''stadium''', '''Label_3''': '''Functional''' } ]
# Index 48 - Response: [ { '''Aspect_1''': '''parking''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''walk''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''Ram's Club area''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''place''', '''Label_4''': '''Functional''' } ]
# Index 49 - Response: [ { '''Aspect_1''': '''seats''', '''Label_1''': '''Monetary''' }, { '''Aspect_2''': '''buffets''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''bathrooms''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''adult beverages''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''indoor viewing''', '''Label_5''': '''Functional''' } ]
# Index 50 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''seating''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''feeling''', '''Label_3''': '''Emotional''' }, { '''Aspect_4''': '''campus''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''concessions''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''rest rooms''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''experience''', '''Label_7''': '''Core''' } ]
# Index 51 - Response: [ { '''Aspect_1''': '''experience''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''Wolfpack football experience''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''game days''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''people''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''team''', '''Label_5''': '''Core''' } ]
# Index 52 - Response: [ { '''Aspect_1''': '''game''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''accessibility''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''route''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''opposing team's color''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''interior''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''staff''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''signage''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''bathrooms''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''seats''', '''Label_9''': '''Functional''' } ]
# Index 53 - Response: [ { '''Aspect_1''': '''bands''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''seats''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''sound system''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''entry''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''bag policy''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''gate staff''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''mobile entry only tickets''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''warnings and restrictions''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''fees''', '''Label_9''': '''Monetary''' }, { '''Aspect_10''': '''experience''', '''Label_10''': '''Others''' } ]
# Index 54 - Response: [ { '''Aspect_1''': '''JMA Wireless Dome''', '''Label_1''': '''Social''' }, { '''Aspect_2''': '''air conditioning''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''food prices''', '''Label_3''': '''Monetary''' }, { '''Aspect_4''': '''sound system''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''seats''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''seats''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''improvements''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''wind tunnel''', '''Label_8''': '''Functional''' } ]
# Index 55 - Response: [ { '''Aspect_1''': '''visit''', '''Label_1''': '''Others''' }, { '''Aspect_2''': '''tickets''', '''Label_2''': '''Monetary''' }, { '''Aspect_3''': '''accessibility''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''Dome''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''arena''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''experience''', '''Label_6''': '''Emotional''' } ]
# Index 56 - Response: [ { '''Aspect_1''': '''visit''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''renovation''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''concourses''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''concession stands''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''men's restrooms''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''ushers and security personnel''', '''Label_6''': '''Safety''' }, { '''Aspect_7''': '''Syracuse students/fans''', '''Label_7''': '''Safety''' }, { '''Aspect_8''': '''language''', '''Label_8''': '''Safety''' }, { '''Aspect_9''': '''police officer''', '''Label_9''': '''Safety''' }, { '''Aspect_10''': '''parking''', '''Label_10''': '''Functional''' }, { '''Aspect_11''': '''seats''', '''Label_11''': '''Functional''' }, { '''Aspect_12''': '''fans''', '''Label_12''': '''Functional''' } ]
# Index 57 - Response: [ { '''Aspect_1''': '''venue''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''seats''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''assigned "seat" size''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''heat''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''cooling system''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''visit''', '''Label_6''': '''Others''' } ]
# Index 58 - Response: [ { '''Aspect_1''': '''seats''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''seats''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''Syracuse University''', '''Label_3''': '''Others''' }, { '''Aspect_4''': '''real seats''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''Women's Bathrooms''', '''Label_5''': '''Functional''' } ]
# Index 59 - Response: [ { '''Aspect_1''': '''Syracuse football game''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''Carrier Dome''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''campus''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''Carrier Dome''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''concourse and bathrooms''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''band members''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''athletics''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''building''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''banners or orange and blue colored lights''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''industrial look''', '''Label_10''': '''Functional''' }, { '''Aspect_11''': '''schtick''', '''Label_11''': '''Functional''' }, { '''Aspect_12''': '''UF games''', '''Label_12''': '''Functional''' }, { '''Aspect_13''': '''Orange''', '''Label_13''': '''Functional''' } ]
# Index 60 - Response: [ { '''Aspect_1''': '''recommendation''', '''Label_1''': '''Others''' }, { '''Aspect_2''': '''impression''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''entrance''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''security''', '''Label_4''': '''Safety''' }, { '''Aspect_5''': '''entry lines''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''magnetometers''', '''Label_6''': '''Safety''' }, { '''Aspect_7''': '''stadium design''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''concourse''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''hot chocolate''', '''Label_9''': '''Monetary''' }, { '''Aspect_10''': '''water bottles''', '''Label_10''': '''Monetary''' }, { '''Aspect_11''': '''parking''', '''Label_11''': '''Functional''' }, { '''Aspect_12''': '''seating''', '''Label_12''': '''Functional''' }, { '''Aspect_13''': '''seat cushions''', '''Label_13''': '''Functional''' }, { '''Aspect_14''': '''views''', '''Label_14''': '''Functional''' }, { '''Aspect_15''': '''scoreboard and sound system''', '''Label_15''': '''Functional''' }, { '''Aspect_16''': '''scoreboard''', '''Label_16''': '''Functional''' }, { '''Aspect_17''': '''impression''', '''Label_17''': '''Emotional''' }, { '''Aspect_18''': '''parking''', '''Label_18''': '''Functional''' } ]
# Index 61 - Response: [ { '''Aspect_1''': '''bag policy''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''bag policy''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''wife's experience''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''umbrellas''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''parking''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''visitor treatment''', '''Label_6''': '''Functional''' } ]
# Index 62 - Response: [ { '''Aspect_1''': '''college football games''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''venue''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''benches''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''stadium''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''experience''', '''Label_5''': '''Emotional''' }, { '''Aspect_6''': '''crowds''', '''Label_6''': '''Social''' }, { '''Aspect_7''': '''parking''', '''Label_7''': '''Functional''' } ]
# Index 63 - Response: [ { '''Aspect_1''': '''Scott Stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''architecture''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''restrooms and concessions''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''experience''', '''Label_4''': '''Emotional''' }, { '''Aspect_5''': '''parking''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''shuttles''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''Landon's football team''', '''Label_7''': '''Core''' } ]
# Index 64 - Response: [ { '''Aspect_1''': '''Lane Stadium''', '''Label_1''': '''Core''' }, { '''Aspect_2''': '''atmosphere''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''spirit''', '''Label_3''': '''Emotional''' }, { '''Aspect_4''': '''volume''', '''Label_4''': '''Emotional''' }, { '''Aspect_5''': '''amenities''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''women's bathrooms''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''seating''', '''Label_7''': '''Functional''' } ]
# Index 65 - Response: [ { '''Aspect_1''': '''atmosphere''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''team's entrance''', '''Label_2''': '''Core''' } ]
# Index 66 - Response: [ { '''Aspect_1''': '''recommendation''', '''Label_1''': '''Others''' }, { '''Aspect_2''': '''passion''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''pre-game rituals''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''atmosphere''', '''Label_4''': '''Emotional''' }, { '''Aspect_5''': '''team performance''', '''Label_5''': '''Core''' } ]
# Index 67 - Response: [ { '''Aspect_1''': '''tailgaters''', '''Label_1''': '''Social''' }, { '''Aspect_2''': '''team's entry''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''fly over''', '''Label_3''': '''Emotional''' }, { '''Aspect_4''': '''ticket''', '''Label_4''': '''Monetary''' } ]
# Index 68 - Response: [ { '''Aspect_1''': '''enthusiastic crowds''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''Enter Sandman''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''military tradition''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''transition between the third and fourth quarters''', '''Label_4''': '''Social''' } ]
# Index 69 - Response: [ { '''Aspect_1''': '''place''', '''Label_1''': '''Social''' }, { '''Aspect_2''': '''stadium''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''students''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''seats''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''enclosing the stadium''', '''Label_5''': '''Functional''' } ]
# Index 70 - Response: [ { '''Aspect_1''': '''experience''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''VA Tech fans''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''VA Tech entrance''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''evergreen trees''', '''Label_4''': '''Others''' } ]
# Index 71 - Response: [ { '''Aspect_1''': '''stadiums''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''Hokie fans''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''traditions''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''Hokie fans''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''Hokie fans''', '''Label_5''': '''Social''' }, { '''Aspect_6''': '''Hokie fans''', '''Label_6''': '''Social''' }, { '''Aspect_7''': '''Hokie fans''', '''Label_7''': '''Social''' }, { '''Aspect_8''': '''Hokie fans''', '''Label_8''': '''Social''' }, { '''Aspect_9''': '''Hokie fans''', '''Label_9''': '''Social''' }, { '''Aspect_10''': '''parking and post-game traffic''', '''Label_10''': '''Functional''' }, { '''Aspect_11''': '''parking''', '''Label_11''': '''Functional''' }, { '''Aspect_12''': '''post-game traffic''', '''Label_12''': '''Functional''' }, { '''Aspect_13''': '''experience''', '''Label_13''': '''Emotional''' } ]
# Index 72 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''feeling''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''seating area''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''experience''', '''Label_4''': '''Core''' }, { '''Aspect_5''': '''Hokie Pokie''', '''Label_5''': '''Social''' }, { '''Aspect_6''': '''tuba section''', '''Label_6''': '''Social''' }, { '''Aspect_7''': '''NCAA ACC Football''', '''Label_7''': '''Core''' }, { '''Aspect_8''': '''sign''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''HokieShop''', '''Label_9''': '''Functional''' } ]
# Index 73 - Response: [ { '''Aspect_1''': '''season tickets''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''college football''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''"Enter Sandman"''', '''Label_3''': '''Emotional''' }, { '''Aspect_4''': '''recommendation''', '''Label_4''': '''Others''' } ]
# Index 74 - Response: [ { '''Aspect_1''': '''college football place''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''college venue''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''tradition''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''food selections''', '''Label_4''': '''Functional''' } ]
# Index 75 - Response: [ { '''Aspect_1''': '''visit''', '''Label_1''': '''Others''' }, { '''Aspect_2''': '''tailgating''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''game''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''owner's suites''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''experience''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''"Enter Sandman" by Metallica''', '''Label_6''': '''Social''' } ]
# Index 76 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''stadium size''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''fans''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''fireworks and canon shots''', '''Label_4''': '''Functional''' } ]
# Index 77 - Response: [ { '''Aspect_1''': '''venue''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''venue''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''stadium''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''jumbo screens''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''Fan Zone''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''perk''', '''Label_6''': '''Monetary''' }, { '''Aspect_7''': '''seating''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''luxury seats''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''transportation''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''Cal fans''', '''Label_10''': '''Social''' } ]
# Index 78 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''stadium''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''stadium''', '''Label_3''': '''Functional''' } ]
# Index 79 - Response: [ { '''Aspect_1''': '''Cal Memorial Stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''seismic damage and instability''', '''Label_2''': '''Safety''' }, { '''Aspect_3''': '''reconstruction''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''bench seating''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''rented chair back''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''concessions''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''view''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''tightwad hill''', '''Label_8''': '''Social''' } ]
# Index 80 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''Jumbotron''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''seats''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''bathrooms''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''security staff''', '''Label_5''': '''Safety''' }, { '''Aspect_6''': '''experience''', '''Label_6''': '''Emotional''' } ]
# Index 81 - Response: [ { '''Aspect_1''': '''football game''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''teams''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''game outcome''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''season tickets''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''reserved parking''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''honoring other sports championship athletics''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''mascot''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''entertainment''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''Bear Roar''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''competition''', '''Label_10''': '''Functional''' }, { '''Aspect_11''': '''half time''', '''Label_11''': '''Functional''' }, { '''Aspect_12''': '''stadium''', '''Label_12''': '''Functional''' } ]
# Index 82 - Response: [ { '''Aspect_1''': '''season ticket holders''', '''Label_1''': '''Monetary''' }, { '''Aspect_2''': '''stadium''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''game outcome''', '''Label_3''': '''Core''' }, { '''Aspect_4''': '''Cal Band''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''athletes''', '''Label_5''': '''Core''' }, { '''Aspect_6''': '''cheerleaders''', '''Label_6''': '''Social''' }, { '''Aspect_7''': '''mascots''', '''Label_7''': '''Social''' }, { '''Aspect_8''': '''stadium name''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''television coverage''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''presentations and fan participation activities''', '''Label_10''': '''Social''' }, { '''Aspect_11''': '''stuffed black bear''', '''Label_11''': '''Functional''' } ]
# Index 83 - Response: [ { '''Aspect_1''': '''recommendation''', '''Label_1''': '''Others''' }, { '''Aspect_2''': '''audience''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''student section''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''BART''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''BART riders''', '''Label_5''': '''Social''' }, { '''Aspect_6''': '''Stanford/Cal game''', '''Label_6''': '''Social''' }, { '''Aspect_7''': '''directions''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''ticket purchase''', '''Label_8''': '''Monetary''' }, { '''Aspect_9''': '''Berkeley ticket website''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''experience''', '''Label_10''': '''Emotional''' } ]
# Index 84 - Response: [ { '''Aspect_1''': '''game''', '''Label_1''': '''Social''' }, { '''Aspect_2''': '''pre-game atmosphere''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''cheerleaders''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''SMU Alumni band''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''tailgating''', '''Label_5''': '''Social''' }, { '''Aspect_6''': '''seating''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''restrooms''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''food''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''food trucks''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''snow cone''', '''Label_10''': '''Functional''' }, { '''Aspect_11''': '''price''', '''Label_11''': '''Monetary''' }, { '''Aspect_12''': '''George W. Bush''', '''Label_12''': '''Social''' }, { '''Aspect_13''': '''parking''', '''Label_13''': '''Functional''' }, { '''Aspect_14''': '''parking suggestion''', '''Label_14''': '''Functional''' }, { '''Aspect_15''': '''ticket prices''', '''Label_15''': '''Monetary''' } ]
# Index 85 - Response: [ { '''Aspect_1''': '''Texas Stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''renovation''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''transportation''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''tailgating''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''Corral''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''SMU Alumni Band''', '''Label_6''': '''Social''' }, { '''Aspect_7''': '''stadium''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''food options''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''bottled water''', '''Label_9''': '''Monetary''' }, { '''Aspect_10''': '''Mustang Band''', '''Label_10''': '''Social''' }, { '''Aspect_11''': '''Peruna''', '''Label_11''': '''Social''' }, { '''Aspect_12''': '''SMU football games''', '''Label_12''': '''Core''' }, { '''Aspect_13''': '''meeting people''', '''Label_13''': '''Social''' } ]
# Index 86 - Response: [ { '''Aspect_1''': '''game experience''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''postgame experience''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''ASU game''', '''Label_3''': '''Core''' }, { '''Aspect_4''': '''print-at-home tickets''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''water fountains or restrooms''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''McKale Ticket Office''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''Gate 2''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''security check''', '''Label_8''': '''Safety''' }, { '''Aspect_9''': '''purse search''', '''Label_9''': '''Safety''' }, { '''Aspect_10''': '''seats''', '''Label_10''': '''Functional''' }, { '''Aspect_11''': '''security guard''', '''Label_11''': '''Safety''' }, { '''Aspect_12''': '''stadium''', '''Label_12''': '''Functional''' }, { '''Aspect_13''': '''Arizona blowout loss to UCLA''', '''Label_13''': '''Core''' }, { '''Aspect_14''': '''medical issues''', '''Label_14''': '''Safety''' }, { '''Aspect_15''': '''parking garage''', '''Label_15''': '''Functional''' }, { '''Aspect_16''': '''students''', '''Label_16''': '''Social''' }, { '''Aspect_17''': '''family experience''', '''Label_17''': '''Emotional''' }, { '''Aspect_18''': '''U of A football recruiting''', '''Label_18''': '''Core''' } ]
# Index 87 - Response: [ { '''Aspect_1''': '''marching band''', '''Label_1''': '''Social''' }, { '''Aspect_2''': '''marching band''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''crowds''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''crowds at other places''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''venue''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''experience for kids''', '''Label_6''': '''Social''' }, { '''Aspect_7''': '''canned music and sound effects''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''canned music and sound effects''', '''Label_8''': '''Functional''' } ]
# Index 88 - Response: [ { '''Aspect_1''': '''lines of sight''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''stadium layout''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''parking''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''transportation''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''seating''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''concourse''', '''Label_6''': '''Functional''' } ]
# Index 89 - Response: [ { '''Aspect_1''': '''visit''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''indoctrination''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''security''', '''Label_3''': '''Safety''' }, { '''Aspect_4''': '''seats''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''drinks and food''', '''Label_5''': '''Monetary''' }, { '''Aspect_6''': '''experience''', '''Label_6''': '''Emotional''' }, { '''Aspect_7''': '''recommendation''', '''Label_7''': '''Functional''' } ]
# Index 90 - Response: [ { '''Aspect_1''': '''views''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''facility''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''stairs''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''ramps''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''transport carts''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''restroom facilities''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''vendors''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''light rail''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''atmosphere''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''screens''', '''Label_10''': '''Functional''' }, { '''Aspect_11''': '''fireworks''', '''Label_11''': '''Functional''' }, { '''Aspect_12''': '''uniforms''', '''Label_12''': '''Social''' }, { '''Aspect_13''': '''location''', '''Label_13''': '''Functional''' } ]
# ...
# Index 854 - Response: [ { '''Aspect_1''': '''renovations''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''ladies' room''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''towers''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''improvements''', '''Label_4''': '''Functional''' } ]
# Index 855 - Response: [ { '''Aspect_1''': '''experience''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''place''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''Aggie's''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''Aggie's''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''gift shops and concessions''', '''Label_5''': '''Functional''' } ]
# Index 856 - Response: [ { '''Aspect_1''': '''place''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''spirit in the stadium''', '''Label_2''': '''Emotional''' }, { '''Aspect_3''': '''Aggies''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''Fightin' Texas Aggie Band''', '''Label_4''': '''Social''' } ]
# Index 857 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''location''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''seating capacity''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''game attendance''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''12th Man''', '''Label_5''': '''Social''' }, { '''Aspect_6''': '''Fightin' Texas Aggie Band''', '''Label_6''': '''Social''' }, { '''Aspect_7''': '''Aggie Band''', '''Label_7''': '''Social''' }, { '''Aspect_8''': '''tradition''', '''Label_8''': '''Social''' }, { '''Aspect_9''': '''visitors''', '''Label_9''': '''Social''' } ]
# Index 858 - Response: [ { '''Aspect_1''': '''place''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''A&M fans''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''stadium''', '''Label_3''': '''Emotional''' }, { '''Aspect_4''': '''venue''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''recommendation''', '''Label_5''': '''Social''' }, { '''Aspect_6''': '''game''', '''Label_6''': '''Emotional''' }, { '''Aspect_7''': '''A&M fans''', '''Label_7''': '''Social''' } ]
# Index 859 - Response: [ { '''Aspect_1''': '''football stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''sculptures''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''visit''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''Gig 'em''', '''Label_4''': '''Social''' } ]
# Index 860 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''seats''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''cushion seat''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''air conditioned area concessions''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''shade or inclement weather''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''loudest college stadiums''', '''Label_6''': '''Emotional''' } ]
# Index 861 - Response: [ { '''Aspect_1''': '''recommendation''', '''Label_1''': '''Social''' }, { '''Aspect_2''': '''traditional cheers''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''crowd noise''', '''Label_3''': '''Emotional''' }, { '''Aspect_4''': '''Fightin' Texas Aggie Band half time performance''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''renovation''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''accessibility''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''escalators''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''premium seats and suites''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''food options''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''unique Texas items''', '''Label_10''': '''Functional''' }, { '''Aspect_11''': '''alcohol''', '''Label_11''': '''Functional''' } ]
# Index 862 - Response: [ { '''Aspect_1''': '''renovation''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''Hall of Champions''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''dedication and work of college athletes''', '''Label_3''': '''Core''' }, { '''Aspect_4''': '''technology used in the exhibits''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''photo''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''Aggie game''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''food in the All American Club''', '''Label_7''': '''Functional''' } ]
# Index 863 - Response: [ { '''Aspect_1''': '''college football stadium''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''seats''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''food''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''food''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''place''', '''Label_5''': '''Emotional''' } ]
# Index 864 - Response: [ { '''Aspect_1''': '''update''', '''Label_1''': '''Others''' }, { '''Aspect_2''': '''special spiced hot dogs''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''town''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''stadium''', '''Label_4''': '''Core''' } ]
# Index 865 - Response: [ { '''Aspect_1''': '''student section''', '''Label_1''': '''Social''' }, { '''Aspect_2''': '''remodel''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''place to be a "Visitor"''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''welcoming atmosphere''', '''Label_4''': '''Social''' } ]
# Index 866 - Response: [ { '''Aspect_1''': '''renovated football stadium and athletic complex''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''Kyle Field''', '''Label_2''': '''Functional''' } ]
# Index 867 - Response: [ { '''Aspect_1''': '''kindness''', '''Label_1''': '''Social''' }, { '''Aspect_2''': '''tradition''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''beauty''', '''Label_3''': '''Others''' }, { '''Aspect_4''': '''visit recommendation''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''Texas hospitality''', '''Label_5''': '''Social''' }, { '''Aspect_6''': '''eating recommendation''', '''Label_6''': '''Functional''' } ]
# Index 868 - Response: [ { '''Aspect_1''': '''scale''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''stadium''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''parking''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''fans''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''traffic''', '''Label_5''': '''Functional''' } ]
# Index 869 - Response: [ { '''Aspect_1''': '''stadium''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''upgrades''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''SEC fans''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''seats''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''marching band's halftime performance''', '''Label_5''': '''Core''' } ]
# Index 870 - Response: [ { '''Aspect_1''': '''renovation''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''crowd''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''seats''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''new section''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''game''', '''Label_5''': '''Core''' }, { '''Aspect_6''': '''entrance''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''organization''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''entrance''', '''Label_8''': '''Functional''' }, { '''Aspect_9''': '''line''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''bag rules''', '''Label_10''': '''Functional''' }, { '''Aspect_11''': '''communication''', '''Label_11''': '''Functional''' }, { '''Aspect_12''': '''water fountains''', '''Label_12''': '''Functional''' }, { '''Aspect_13''': '''severe weather delay''', '''Label_13''': '''Safety''' }, { '''Aspect_14''': '''jumbotron''', '''Label_14''': '''Functional''' }, { '''Aspect_15''': '''announcement''', '''Label_15''': '''Functional''' }, { '''Aspect_16''': '''experience''', '''Label_16''': '''Functional''' } ]
# Index 871 - Response: [ { '''Aspect_1''': '''Kyle's field''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''construction''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''updates''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''excitement''', '''Label_4''': '''Emotional''' } ]
# Index 872 - Response: [ { '''Aspect_1''': '''Kyle Field''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''family friendly event''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''food''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''crowd''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''parking''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''help''', '''Label_6''': '''Functional''' }, { '''Aspect_7''': '''Corps march''', '''Label_7''': '''Social''' }, { '''Aspect_8''': '''Aggie Spirit''', '''Label_8''': '''Social''' }, { '''Aspect_9''': '''Yell Leaders''', '''Label_9''': '''Social''' }, { '''Aspect_10''': '''Johnny Football''', '''Label_10''': '''Emotional''' } ]
# Index 873 - Response: [ { '''Aspect_1''': '''renovation''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''visitors''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''recommendation''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''tailgating and BBQ''', '''Label_4''': '''Social''' } ]
# Index 874 - Response: [ { '''Aspect_1''': '''Texas A&M Aggie home football games''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''Kyle Field''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''atmosphere''', '''Label_3''': '''Emotional''' }, { '''Aspect_4''': '''Fightin' Texas Aggie Band''', '''Label_4''': '''Functional''' }, { '''Aspect_5''': '''SEC''', '''Label_5''': '''Core''' }, { '''Aspect_6''': '''Corps of Cadets''', '''Label_6''': '''Social''' }, { '''Aspect_7''': '''stadium''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''12th Man''', '''Label_8''': '''Social''' } ]
# Index 875 - Response: [ { '''Aspect_1''': '''tradition''', '''Label_1''': '''Social''' }, { '''Aspect_2''': '''Kyle Field''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''corps march''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''Sawing Varsity's Horns Off''', '''Label_4''': '''Social''' }, { '''Aspect_5''': '''SEC conference play''', '''Label_5''': '''Social''' }, { '''Aspect_6''': '''tailgating''', '''Label_6''': '''Social''' } ]
# Index 876 - Response: [ { '''Aspect_1''': '''facility''', '''Label_1''': '''Functional''' }, { '''Aspect_2''': '''team''', '''Label_2''': '''Core''' }, { '''Aspect_3''': '''fans''', '''Label_3''': '''Social''' }, { '''Aspect_4''': '''recommendation''', '''Label_4''': '''Others''' }, { '''Aspect_5''': '''people''', '''Label_5''': '''Social''' } ]
# Index 877 - Response: [ { '''Aspect_1''': '''football games''', '''Label_1''': '''Emotional''' }, { '''Aspect_2''': '''stadium''', '''Label_2''': '''Functional''' }, { '''Aspect_3''': '''stadium architecture''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''game day atmosphere''', '''Label_4''': '''Emotional''' }, { '''Aspect_5''': '''east side''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''students''', '''Label_6''': '''Social''' }, { '''Aspect_7''': '''halftime''', '''Label_7''': '''Functional''' }, { '''Aspect_8''': '''coordinated yells''', '''Label_8''': '''Social''' }, { '''Aspect_9''': '''west side''', '''Label_9''': '''Functional''' }, { '''Aspect_10''': '''Aggie fans''', '''Label_10''': '''Social''' }, { '''Aspect_11''': '''The Zone''', '''Label_11''': '''Functional''' }, { '''Aspect_12''': '''view''', '''Label_12''': '''Functional''' }, { '''Aspect_13''': '''armchair seats''', '''Label_13''': '''Functional''' }, { '''Aspect_14''': '''restrooms''', '''Label_14''': '''Functional''' }, { '''Aspect_15''': '''stadium renovations''', '''Label_15''': '''Functional''' }, { '''Aspect_16''': '''walking shoes''', '''Label_16''': '''Functional''' }, { '''Aspect_17''': '''elevators''', '''Label_17''': '''Functional''' }, { '''Aspect_18''': '''weather''', '''Label_18''': '''Functional''' }, { '''Aspect_19''': '''sunscreen''', '''Label_19''': '''Functional''' }, { '''Aspect_20''': '''policies''', '''Label_20''': '''Functional''' }, { '''Aspect_21''': '''alcohol''', '''Label_21''': '''Functional''' }, { '''Aspect_22''': '''strollers''', '''Label_22''': '''Functional''' }, { '''Aspect_23''': '''umbrellas''', '''Label_23''': '''Functional''' }, { '''Aspect_24''': '''cell phone access''', '''Label_24''': '''Functional''' }, { '''Aspect_25''': '''game day information''', '''Label_25''': '''Functional''' }, { '''Aspect_26''': '''Fan Zone''', '''Label_26''': '''Functional''' }, { '''Aspect_27''': '''pre-game flyover''', '''Label_27''': '''Functional''' }, { '''Aspect_28''': '''college football venue''', '''Label_28''': '''Emotional''' } ]
# Index 878 - Response: [ { '''Aspect_1''': '''Kyle Field''', '''Label_1''': '''Core''' }, { '''Aspect_2''': '''pregame atmosphere''', '''Label_2''': '''Social''' }, { '''Aspect_3''': '''local sausage''', '''Label_3''': '''Functional''' }, { '''Aspect_4''': '''Fighting Texas Aggie Band''', '''Label_4''': '''Core''' }, { '''Aspect_5''': '''stadium''', '''Label_5''': '''Functional''' }, { '''Aspect_6''': '''new stadium''', '''Label_6''': '''Functional''' } ]
#     ID                    Experience_date Written_date Conference  Stadium  \
# 0   99   Date of experience: October 2016    13-May-17        ACC  Clemson
# 1  113  Date of experience: November 2016    30-Nov-16        ACC  Clemson
# 2  156  Date of experience: November 2015     1-Mar-16        ACC  Clemson
# 3  168  Date of experience: November 2015    23-Nov-15        ACC  Clemson
# 4  177   Date of experience: October 2015    24-Oct-15        ACC  Clemson
#
#    Rating                                       Review_title  \
# 0       5                       Awesome football experience!
# 1       5                                 Awesome experience
# 2       4                              The time of your life
# 3       4  Great atmosphere & place to tailgate, don't en...
# 4       5                            Awesome experience!!!!!
#
#                                                 Text  \
# 0  We love going to football games at Death Valle...
# 1  If you are able to buy tickets to see a Clemso...
# 2  Memorial Stadium, otherwise known as Death Val...
# 3  Great atmosphere to see a football game, nice ...
# 4  Our seats were way up high in corner and yet I...
#
#                                               Aspect  \
# 0  [ {  "Aspect_1": "football games", "Details_1"...
# 1  [ {  "Aspect_1": "recommendation", "Details_1"...
# 2  [ {  "Aspect_1": "Memorial Stadium", "Details_...
# 3  [ {  "Aspect_1": "atmosphere", "Details_1": "g...
# 4  [ {  "Aspect_1": "seats", "Details_1": "Our se...
#
#                                                Label  \
# 0  [ {  "Aspect_1": "football games", "Label_1": ...
# 1  [ {  "Aspect_1": "recommendation", "Label_1": ...
# 2  [ {  "Aspect_1": "Memorial Stadium", "Label_1"...
# 3  [ {  "Aspect_1": "atmosphere", "Label_1": "Emo...
# 4  [ {  "Aspect_1": "seats", "Label_1": "Function...
#
#                                              Aspect1  \
# 0  [ { '''Aspect_1''': '''football games''', '''D...
# 1  [ { '''Aspect_1''': '''recommendation''', '''D...
# 2  [ { '''Aspect_1''': '''Memorial Stadium''', ''...
# 3  [ { '''Aspect_1''': '''atmosphere''', '''Detai...
# 4  [ { '''Aspect_1''': '''seats''', '''Details_1'...
#
#                                               Label1
# 0  [ { '''Aspect_1''': '''football games''', '''L...
# 1  [ { '''Aspect_1''': '''recommendation''', '''L...
# 2  [ { '''Aspect_1''': '''Memorial Stadium''', ''...
# 3  [ { '''Aspect_1''': '''atmosphere''', '''Label...
# 4  [ { '''Aspect_1''': '''seats''', '''Label_1'''...

# %% [markdown]
# **ft:gpt-3.5-turbo-1106:qian:cx-cc:8kEGZJwe**

# %%
import os
import openai as OpenAI
import pandas as pd

# Set up OpenAI API Key securely
client = OpenAI.Client(api_key='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')

# Load the CSV file
df = pd.read_csv('/content/drive/MyDrive/Fine-tune/INF/OUTPUT/Reviews14_AE_errors.csv')

# Create a new column in the DataFrame to store the results
df['Label'] = ''

# Define the system prompt
system_prompt = ("""
    You are an expert in college football, specializing in categorizing aspects of the college football game day experience, identified from Tripadvisor online reviews of college football stadiums.
    Each identified aspect ('Aspect_i') has a corresponding description ('Details_i') that you will use to determine its appropriate category.
    The categories are 'Core', 'Functional', 'Emotional', 'Monetary', 'Social', 'Safety', and 'Others'. Your task is to analyze each aspect's description and classify it accordingly.
    Ensure each step is taken one at a time for optimal clarity and results:
    1. Examine the description ('Details_i') of each aspect ('Aspect_i').
    2. Classify 'Aspect_i' into one of the following categories based on 'Details_i':
    'Core': Sports-related attributes (e.g., team dynamics, game quality). 'Functional': utilitarian services (e.g., facilities, concessions, parking). 'Emotional': Feelings or emotional states (e.g., excitement, thrill).
    'Monetary': Pricing aspects (e.g., affordability, value for money). 'Social': Interpersonal and community aspects (e.g., fan interactions, traditions). 'Safety': Security and safety experiences (e.g., measures, feelings of safety).
    'Others': Aspects unrelated to the college football game day experience or that do not fit into the other categories, such as general comments about the city or weather conditions.
    3. Format this classification into a JSON structure using 'Aspect_i' and 'Label_i' as keys, incrementally assigning 'i' for each aspect.
"""
)

for index, row in df.iterrows():
    if pd.notna(row['Aspect']):
        conversation = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": row['Aspect']}
        ]

        try:
            response = client.chat.completions.create(
                model="ft:gpt-3.5-turbo-1106:qian:cx-cc:8kEGZJwe",
                messages=conversation,
                temperature=0,
                max_tokens=2048
            )

            # Assuming the response is an object with attributes, we use dot notation
            # If this raises an error, then your environment may be different and require dictionary access
            content = response.choices[0].message.content

            # Debug: Print the response
            print(f"Index {index} - Response: {content}")

            # Assign the response to the DataFrame
            df.at[index, 'Label'] = content

        except Exception as e:
            print(f"Error processing index {index}: {e}")
    else:
        print(f"Skipping index {index}: 'Text' column is NaN")

# Debug: Print the DataFrame before saving
print(df.head())

# Save the DataFrame
df.to_csv('/content/drive/MyDrive/Fine-tune/INF/OUTPUT/Reviews14_AE_CC.csv', index=False)
